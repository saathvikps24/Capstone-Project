# %% [markdown]
# #  Crimes in India - Capstone project

# %% [markdown]
# ### Phase - 1

# %% [markdown]
# #### Data Collection/preparation

# %% [markdown]
# In this part or phase of the project, I have extracted data for the population and literacy rate of each state and other required data (from the files) given for the analysis purpose.

# %% [markdown]
# Assumptions:
# As there were less data info provided for population and literacy rate for each year as these both records were recorded once in 10 years (census), I have assumed the data for each year by the growth rate the two variables (population and literacy rate) and divided the growth rate by 10 (for 10 years) so that we get the percentage the growth rate increased for each year.
#
# Below given is the data extraction method.

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
df1 = pd.read_excel("C:/Users/user/Documents/State_Wise_Population.xlsx")
df2 = pd.read_excel("C:/Users/user/Documents/State_wise_Literacy_rate.xlsx")
df1
# Out:
#    States and UT's of India  Population - In 2001  \
# 0            ANDHRA PRADESH              76210007
# 1         ARUNACHAL PRADESH               1097968
# 2                     ASSAM              26655528
# 3                     BIHAR              82998509
# 4              CHHATTISGARH              20833803
# 5                       GOA               1347668
# 6                   GUJARAT              50671017
# 7                   HARYANA              21144564
# 8          HIMACHAL PRADESH               6077900
# 9           JAMMU & KASHMIR              10143700
# 10                JHARKHAND              26945829
# 11                KARNATAKA              52850562
# 12                   KERALA              31841374
# 13           MADHYA PRADESH              60348023
# 14              MAHARASHTRA              96878627
# 15                  MANIPUR               2293896
# 16                MEGHALAYA               2318822
# 17                  MIZORAM                888573
# ...

# %%
df2
# Out:
#    States and UT's of India  Literacy rate in 2001 (in %)  \
# 0            ANDHRA PRADESH                         66.64
# 1         ARUNACHAL PRADESH                         54.34
# 2                     ASSAM                         63.25
# 3                     BIHAR                         47.00
# 4              CHHATTISGARH                         64.66
# 5                       GOA                         82.01
# 6                   GUJARAT                         69.14
# 7                   HARYANA                         67.91
# 8          HIMACHAL PRADESH                         76.48
# 9           JAMMU & KASHMIR                         55.52
# 10                JHARKHAND                         53.56
# 11                KARNATAKA                         60.47
# 12                   KERALA                         90.86
# 13           MADHYA PRADESH                         63.74
# 14              MAHARASHTRA                         76.88
# ...

# %% [markdown]
# Below is the final data that I will be using for my analysis of crime rates in India.

# %%
final = pd.read_csv("C:/Users/user/Documents/STATE_WISE_CRIME_REPORT(2001-2010).csv")
final
# Out:
#     States and UT's of India  Year     POPULATION  LITERACY RATE  Murder  \
# 0             ANDHRA PRADESH  2001   7,62,10,007           66.64      15
# 1             ANDHRA PRADESH  2002   7,70,46,793           67.24      23
# 2             ANDHRA PRADESH  2003   7,78,92,767           67.84      40
# 3             ANDHRA PRADESH  2004   7,87,48,029           68.45      26
# 4             ANDHRA PRADESH  2005   7,96,12,683           69.06      31
# ..                       ...   ...            ...            ...     ...
# 345               PUDUCHERRY  2006     11,19,044           83.42       0
# 346               PUDUCHERRY  2007     11,50,467           83.86       1
# 347               PUDUCHERRY  2008     11,82,772           84.31       2
# 348               PUDUCHERRY  2009     12,15,985           84.76      10
# 349               PUDUCHERRY  2010     12,50,129           85.21       6
#
#      Attempt to Commit Murder  C H Not amounting to Murder  Rape  \
# ...

# %% [markdown]
# Reference link:
# https://www.census2011.co.in/
